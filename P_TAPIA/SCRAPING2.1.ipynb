# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

lista_noticias = []

#marcado de página
response = requests.get("https://cnnespanol.cnn.com/category/alimentos/")
content = response.content
site = BeautifulSoup(content, 'html.parser') #parse (analizador)

#bloque donde se encuantra cada noticia
noticias = site.findAll('article', class_ = 'news') 

#iteración para obtener los datos que queremos extraer 
for noticia in noticias:
    titulo = noticia.find('h2', class_ =  'news__title').text
    link = noticia.find('h2', class_='news__title').a.get('href')
    lista_noticias.append([titulo.strip(),link])
    lista_noticias

#Generar dataframe
news = pd.DataFrame(lista_noticias, columns=['Título', 'Link'])

#exportamos dataframe
news.to_csv('noticias.csv', index=False)
print(lista_noticias)
# Out:
# [['¿Dónde venden la mejor pizza de EE.UU.?', 'https://cnnespanol.cnn.com/video/mejor-pizza-de-eeuu-enciclopedia-modernist-pizza-vo-jennifer-montoya-cafe-cnne/'], ['¿Es bueno o malo consumir huevos todos los días?', 'https://cnnespanol.cnn.com/2021/07/19/comer-huevos-todos-los-dias-bueno-malo-salud/'], ['Día Nacional del Helado: ¿cuál es el sabor más popular?', 'https://cnnespanol.cnn.com/2021/07/18/ofertas-dia-nacional-helado-estados-unidos-festividad-trax/'], ['Expertos recomiendan una dieta con granos enteros', 'https://cnnespanol.cnn.com/video/alimentacion-granos-enteros-saludable-presion-arterial-azucar-en-sangre-encuentro-cnn/'], ['Evita estos alimentos que podrían producir las migrañas', 'https://cnnespanol.cnn.com/video/migranas-alimentos-pueden-producirlas-salud-dra-azaret-vls-cnne/'], ['Para esto sirven los bordes de las galletas Ritz', 'https://cnnespanol.cnn.com/video/galletas-ritz-bordes-dentados-funciona-pkg-digital-jeanne-moos/'], ['Por estas razones el tomate puede ser ideal para verano', 'https://cnnespanol.cnn.com/video/por-que-el-tomate-es-bueno-para-el-calor-verano-beneficios-vo-alejandra-oraa-cafe-cnne/'], ['¿Es saludable la pizza?', 'https://cnnespanol.cnn.com/2021/07/05/comer-pizza-saludable-explicacion/'], ['9 alimentos que te ayudarán a dormir mejor', 'https://cnnespanol.cnn.com/2021/07/02/alimentos-para-dormir-mejor-que-comer-antes-de-dormir-trax/'], ['Demasiada comida sureña podría causar muerte repentina', 'https://cnnespanol.cnn.com/2021/07/01/dieta-comida-surena-ataque-cardiaco-repentino-dieta-mediterranea-trax/'], ['¿Ayudan las espinacas a tener músculos fuertes?', 'https://cnnespanol.cnn.com/2021/07/01/pueden-hacerte-fuerte-espinacas-popeye-ciencia-trax/'], ['Mitos y beneficios del ajo, un alimento controversial', 'https://cnnespanol.cnn.com/video/ajo-cocina-mitos-y-beneficios-cnn-redaccion-buenos-aires/'], ['Beber café de cualquier tipo reduce riesgo hepático', 'https://cnnespanol.cnn.com/2021/06/22/beber-cafe-riesgo-enfermedad-hepatica-cancer-higado-trax/'], ['El café es un alimento saludable: ¿mito o realidad?', 'https://cnnespanol.cnn.com/2021/06/21/cafe-alimento-saludable-mito-o-realidad-trax/'], ['La guerra de la leche de avena apenas comienza', 'https://cnnespanol.cnn.com/2021/06/18/la-guerra-de-la-leche-de-avena-apenas-comienza-trax/'], ['El daño de los alimentos ultrapr